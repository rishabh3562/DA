# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabh3562/DA/blob/main/learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle pandas

# %%
from google.colab import files
files.upload()  # Upload your kaggle.json file
# Out:
#      <input type="file" id="files-9d93472e-0baa-4f33-a13c-4174bf825882" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d93472e-0baa-4f33-a13c-4174bf825882">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets download -d simiotic/github-code-snippets-development-sample

import zipfile
with zipfile.ZipFile('github-code-snippets-development-sample.zip', 'r') as zip_ref:
    zip_ref.extractall('.')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/simiotic/github-code-snippets-development-sample
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
#  99% 467M/471M [00:03<00:00, 162MB/s]
# 100% 471M/471M [00:03<00:00, 131MB/s]

# %%
import os
print(os.listdir())  # Check if the ZIP file is present
# Out:
# ['.config', 'snippets-dev', 'data', 'kaggle.json', 'github-code-snippets-development-sample.zip', 'sample_data']

# %%
import zipfile

zip_path = "github-code-snippets-development-sample.zip"  # Update if filename differs
extract_to = "data"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_to)

print("Extraction complete!")
print(os.listdir(extract_to))  # Check extracted files
# Out:
# Extraction complete!
# ['snippets-dev']

# %%
import sqlite3
import pandas as pd

db_path = "data/snippets-dev/snippets-dev.db" or "snippets-dev/snippets-dev.db" # Adjust path if needed
conn = sqlite3.connect(db_path)

# %%
query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql(query, conn)
print(tables)
# Out:
#        name
# 0  snippets

# %%
df = pd.read_sql("SELECT * FROM snippets", conn)
df.head() # Preview the dataset
# Out:
#     id                                            snippet    language  \
# 0  491  test/files/normalise.jpg.png\ntest/files/norma...     DOTFILE
# 1  512  a computer network, with no transfer of a copy...     UNKNOWN
# 2  584  the predecessor has it or can get it with reas...     UNKNOWN
# 3  610    THERE IS NO WARRANTY FOR THE PROGRAM, TO THE...     UNKNOWN
# 4  627  const nconf = require('nconf');\n\nconst db = ...  JavaScript
#
#                  repo_file_name                   github_repo_url  license  \
# 0      NodeBB/NodeBB/.gitignore  https://github.com/NodeBB/NodeBB  GPL-3.0
# 1         NodeBB/NodeBB/LICENSE  https://github.com/NodeBB/NodeBB  GPL-3.0
# 2         NodeBB/NodeBB/LICENSE  https://github.com/NodeBB/NodeBB  GPL-3.0
# 3         NodeBB/NodeBB/LICENSE  https://github.com/NodeBB/NodeBB  GPL-3.0
# 4  NodeBB/NodeBB/test/groups.js  https://github.com/NodeBB/NodeBB  GPL-3.0
#
#                                   commit_hash  starting_line_number  \
# ...

# %%
df.tail(50)
# Out:
#                 id                                            snippet  \
# 4849950  100314990    background-color: #fdfdfe;\n}\n\n.table-ligh...
# 4849951  100315000  \n.table-hover .table-active:hover > td,\n.tab...
# 4849952  100315002  }\n\n.table .thead-light th {\n  color: #49505...
# 4849953  100315006    border: 0;\n}\n\n.table-dark.table-striped t...
# 4849954  100315023    transition: border-color 0.15s ease-in-out, ...
# 4849955  100315037  \n.form-control-file,\n.form-control-range {\n...
# 4849956  100315086    z-index: 5;\n  display: none;\n  max-width: ...
# 4849957  100315104    display: -ms-flexbox;\n  display: flex;\n  -...
# 4849958  100315124    color: #212529;\n  text-decoration: none;\n}...
# 4849959  100315130    border-color: #007bff;\n  box-shadow: none;\...
# 4849960  100315228    box-shadow: 0 0 0 0 rgba(220, 53, 69, 0.5);\...
# 4849961  100315253         \n.fade:not(.show) {\n  opacity: 0;\n}\n\n
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4850000 entries, 0 to 4849999
# Data columns (total 9 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   snippet               object
#  2   language              object
#  3   repo_file_name        object
#  4   github_repo_url       object
#  5   license               object
#  6   commit_hash           object
#  7   starting_line_number  int64
#  8   chunk_size            int64
# dtypes: int64(3), object(6)
# memory usage: 333.0+ MB

# %%
first_cell=df.iloc[0,0] #iloc to access [row,col]
first_cell
# Out:
# 491

# %%
three_row_2_col=df.iloc[0:2,0:3]
three_row_2_col
# Out:
#     id                                            snippet language
# 0  491  test/files/normalise.jpg.png\ntest/files/norma...  DOTFILE
# 1  512  a computer network, with no transfer of a copy...  UNKNOWN

# %%
df1=df[df['id']>497] #df col where id is greater than 497
df1.head(2)
# Out:
#     id                                            snippet language  \
# 1  512  a computer network, with no transfer of a copy...  UNKNOWN
# 2  584  the predecessor has it or can get it with reas...  UNKNOWN
#
#           repo_file_name                   github_repo_url  license  \
# 1  NodeBB/NodeBB/LICENSE  https://github.com/NodeBB/NodeBB  GPL-3.0
# 2  NodeBB/NodeBB/LICENSE  https://github.com/NodeBB/NodeBB  GPL-3.0
#
#                                   commit_hash  starting_line_number  \
# 1  21634e2681fb1329bcbab7b2e19418ebdb1012e1\n                   100
# 2  21634e2681fb1329bcbab7b2e19418ebdb1012e1\n                   460
#
#    chunk_size
# 1           5
# 2           5

# %%
df['language'].value_counts() #unique values in a column
# Out:
# language
# UNKNOWN       1574797
# C              617132
# JavaScript     448591
# Go             405726
# Java           375772
# C++            327126
# JSON           324965
# Python         196465
# Text           171788
# Markdown       148091
# HTML            99226
# Ruby            54692
# Rust            29827
# YAML            29190
# Shell           19147
# Jupyter         12321
# CSV              8855
# DOTFILE          3282
# PowerShell       1950
# Bash              574
# TSV               483
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                  id  starting_line_number  chunk_size
# count  4.850000e+06          4.850000e+06   4850000.0
# mean   5.025500e+07          3.379771e+03         5.0
# std    2.893650e+07          2.665392e+04         0.0
# min    4.910000e+02          0.000000e+00         5.0
# 25%    2.525040e+07          8.000000e+01         5.0
# 50%    5.070838e+07          3.400000e+02         5.0
# 75%    7.529126e+07          1.645000e+03         5.0
# max    1.003160e+08          9.998050e+05         5.0
